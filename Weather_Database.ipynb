# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
#lat_lngs = # YOUR CODE HERE

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alugan
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | sentyabrskiy
# Processing Record 4 of Set 1 | vestmannaeyjar
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | guaraciaba do norte
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | manavalakurichi
# Processing Record 9 of Set 1 | attawapiskat
# Processing Record 10 of Set 1 | bandarbeyla
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | homer
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | port hardy
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | terrace bay
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | necochea
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | labuhan
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | sao filipe
# Processing Record 39 of Set 1 | jining
# Processing Record 40 of Set 1 | sarkand
# Processing Record 41 of Set 1 | faya
# Processing Record 42 of Set 1 | arlit
# Processing Record 43 of Set 1 | klaksvik
# Processing Record 44 of Set 1 | lakhtar
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | dunedin
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | belushya guba
# Processing Record 3 of Set 2 | sobolevo
# Processing Record 4 of Set 2 | byron bay
# Processing Record 5 of Set 2 | adrar
# Processing Record 6 of Set 2 | birao
# Processing Record 7 of Set 2 | sabancuy
# Processing Record 8 of Set 2 | lahaina
# Processing Record 9 of Set 2 | mount pleasant
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | taolanaro
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | clarksburg
# Processing Record 16 of Set 2 | puerto baquerizo moreno
# Processing Record 17 of Set 2 | barstow
# Processing Record 18 of Set 2 | kavieng
# Processing Record 19 of Set 2 | sidi ali
# Processing Record 20 of Set 2 | kloulklubed
# Processing Record 21 of Set 2 | bloomfield
# Processing Record 22 of Set 2 | namatanai
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | kruisfontein
# Processing Record 27 of Set 2 | glad
# Processing Record 28 of Set 2 | yarmolyntsi
# Processing Record 29 of Set 2 | whitehorse
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | kimbe
# Processing Record 32 of Set 2 | khash
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | belyy yar
# Processing Record 36 of Set 2 | codrington
# Processing Record 37 of Set 2 | sheregesh
# Processing Record 38 of Set 2 | beitbridge
# Processing Record 39 of Set 2 | saint anthony
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | iqaluit
# Processing Record 42 of Set 2 | dakar
# Processing Record 43 of Set 2 | grand river south east
# Processing Record 44 of Set 2 | beringovskiy
# Processing Record 45 of Set 2 | sambava
# Processing Record 46 of Set 2 | mezhdurechenskiy
# Processing Record 47 of Set 2 | fukue
# Processing Record 48 of Set 2 | kidal
# Processing Record 49 of Set 2 | vaitupu
# Processing Record 50 of Set 2 | nantucket
# Processing Record 1 of Set 3 | radomsko
# Processing Record 2 of Set 3 | durango
# Processing Record 3 of Set 3 | virginia beach
# Processing Record 4 of Set 3 | talnakh
# Processing Record 5 of Set 3 | taltal
# Processing Record 6 of Set 3 | luoyang
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | illoqqortoormiut
# Processing Record 9 of Set 3 | kalmunai
# Processing Record 10 of Set 3 | hirara
# Processing Record 11 of Set 3 | sioux lookout
# Processing Record 12 of Set 3 | manjeshwar
# Processing Record 13 of Set 3 | tautira
# Processing Record 14 of Set 3 | mys shmidta
# Processing Record 15 of Set 3 | nortelandia
# Processing Record 16 of Set 3 | leh
# Processing Record 17 of Set 3 | tres arroyos
# Processing Record 18 of Set 3 | erzin
# Processing Record 19 of Set 3 | juan lacaze
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | riverton
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | nizhneyansk
# Processing Record 24 of Set 3 | vila
# Processing Record 25 of Set 3 | sao joao da barra
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | ostersund
# Processing Record 28 of Set 3 | gilgit
# Processing Record 29 of Set 3 | bastrop
# Processing Record 30 of Set 3 | mount gambier
# Processing Record 31 of Set 3 | korkmaskala
# Processing Record 32 of Set 3 | bacolod
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | kapuskasing
# Processing Record 35 of Set 3 | goundam
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | butaritari
# Processing Record 38 of Set 3 | avila
# Processing Record 39 of Set 3 | hyeres
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | devonport
# Processing Record 42 of Set 3 | sann
# Processing Record 43 of Set 3 | bathsheba
# Processing Record 44 of Set 3 | lolua
# Processing Record 45 of Set 3 | tabas
# Processing Record 46 of Set 3 | victoria
# Processing Record 47 of Set 3 | barentsburg
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | vao
# Processing Record 50 of Set 3 | bubaque
# Processing Record 1 of Set 4 | tahta
# Processing Record 2 of Set 4 | collie
# Processing Record 3 of Set 4 | ayia anna
# Processing Record 4 of Set 4 | san cristobal
# Processing Record 5 of Set 4 | hasaki
# Processing Record 6 of Set 4 | baykit
# Processing Record 7 of Set 4 | wulanhaote
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | innisfail
# Processing Record 10 of Set 4 | honiara
# Processing Record 11 of Set 4 | klyuchi
# Processing Record 12 of Set 4 | miri
# Processing Record 13 of Set 4 | honningsvag
# Processing Record 14 of Set 4 | coxim
# Processing Record 15 of Set 4 | tevriz
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | norman wells
# Processing Record 18 of Set 4 | cap malheureux
# Processing Record 19 of Set 4 | kalabo
# Processing Record 20 of Set 4 | cidreira
# Processing Record 21 of Set 4 | husavik
# Processing Record 22 of Set 4 | camocim
# Processing Record 23 of Set 4 | bluff
# Processing Record 24 of Set 4 | nadym
# Processing Record 25 of Set 4 | sola
# Processing Record 26 of Set 4 | new norfolk
# Processing Record 27 of Set 4 | sorong
# Processing Record 28 of Set 4 | mosquera
# Processing Record 29 of Set 4 | ilulissat
# Processing Record 30 of Set 4 | huarmey
# Processing Record 31 of Set 4 | bolondron
# Processing Record 32 of Set 4 | gaillac
# Processing Record 33 of Set 4 | grindavik
# Processing Record 34 of Set 4 | gigmoto
# Processing Record 35 of Set 4 | daxian
# Processing Record 36 of Set 4 | kasangulu
# Processing Record 37 of Set 4 | samusu
# Processing Record 38 of Set 4 | sitka
# Processing Record 39 of Set 4 | port lincoln
# Processing Record 40 of Set 4 | tiksi
# Processing Record 41 of Set 4 | turukhansk
# Processing Record 42 of Set 4 | te anau
# Processing Record 43 of Set 4 | mogadishu
# Processing Record 44 of Set 4 | kinanah
# Processing Record 45 of Set 4 | geraldton
# Processing Record 46 of Set 4 | stromness
# Processing Record 47 of Set 4 | anadyr
# Processing Record 48 of Set 4 | narsaq
# Processing Record 49 of Set 4 | am timan
# Processing Record 50 of Set 4 | zhigansk
# Processing Record 1 of Set 5 | vila velha
# Processing Record 2 of Set 5 | chumikan
# Processing Record 3 of Set 5 | andros town
# Processing Record 4 of Set 5 | port macquarie
# Processing Record 5 of Set 5 | cozumel
# Processing Record 6 of Set 5 | gannan
# Processing Record 7 of Set 5 | ulaangom
# Processing Record 8 of Set 5 | ahipara
# Processing Record 9 of Set 5 | cairo
# Processing Record 10 of Set 5 | gat
# Processing Record 11 of Set 5 | lodwar
# Processing Record 12 of Set 5 | sanary-sur-mer
# Processing Record 13 of Set 5 | kaka
# Processing Record 14 of Set 5 | roald
# Processing Record 15 of Set 5 | cefalu
# Processing Record 16 of Set 5 | cassilandia
# Processing Record 17 of Set 5 | ukiah
# Processing Record 18 of Set 5 | luderitz
# Processing Record 19 of Set 5 | cururupu
# Processing Record 20 of Set 5 | matay
# Processing Record 21 of Set 5 | olecko
# Processing Record 22 of Set 5 | mariinsk
# Processing Record 23 of Set 5 | itoman
# Processing Record 24 of Set 5 | lasa
# Processing Record 25 of Set 5 | crab hill
# Processing Record 26 of Set 5 | westport
# Processing Record 27 of Set 5 | liverpool
# Processing Record 28 of Set 5 | gravelbourg
# Processing Record 29 of Set 5 | mehamn
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | ogbomosho
# Processing Record 32 of Set 5 | inverness
# Processing Record 33 of Set 5 | chipinge
# Processing Record 34 of Set 5 | keningau
# Processing Record 35 of Set 5 | aljezur
# Processing Record 36 of Set 5 | cairns
# Processing Record 37 of Set 5 | lebu
# Processing Record 38 of Set 5 | dubbo
# Processing Record 39 of Set 5 | erenhot
# Processing Record 40 of Set 5 | vestnes
# Processing Record 41 of Set 5 | kayes
# Processing Record 42 of Set 5 | leesburg
# Processing Record 43 of Set 5 | yate
# Processing Record 44 of Set 5 | palmer
# Processing Record 45 of Set 5 | terrace
# Processing Record 46 of Set 5 | cape canaveral
# Processing Record 47 of Set 5 | hamilton
# Processing Record 48 of Set 5 | sabang
# Processing Record 49 of Set 5 | vila franca do campo
# Processing Record 50 of Set 5 | ancud
# Processing Record 1 of Set 6 | sao borja
# Processing Record 2 of Set 6 | praia
# Processing Record 3 of Set 6 | aleysk
# Processing Record 4 of Set 6 | khonuu
# Processing Record 5 of Set 6 | tevaitoa
# Processing Record 6 of Set 6 | itaueira
# Processing Record 7 of Set 6 | faanui
# Processing Record 8 of Set 6 | tutoia
# Processing Record 9 of Set 6 | stratonion
# Processing Record 10 of Set 6 | haapiti
# Processing Record 11 of Set 6 | ishigaki
# Processing Record 12 of Set 6 | tymovskoye
# Processing Record 13 of Set 6 | ilhabela
# Processing Record 14 of Set 6 | brumadinho
# Processing Record 15 of Set 6 | samarai
# Processing Record 16 of Set 6 | upata
# Processing Record 17 of Set 6 | maiduguri
# Processing Record 18 of Set 6 | guerrero negro
# Processing Record 19 of Set 6 | meridian
# Processing Record 20 of Set 6 | tazovskiy
# Processing Record 21 of Set 6 | inderborskiy
# Processing Record 22 of Set 6 | lorengau
# Processing Record 23 of Set 6 | quarai
# Processing Record 24 of Set 6 | hualmay
# Processing Record 25 of Set 6 | kishni
# Processing Record 26 of Set 6 | jiroft
# Processing Record 27 of Set 6 | teguise
# Processing Record 28 of Set 6 | vestmanna
# Processing Record 29 of Set 6 | eureka
# Processing Record 30 of Set 6 | cordoba
# Processing Record 31 of Set 6 | kaitangata
# Processing Record 32 of Set 6 | bud
# Processing Record 33 of Set 6 | jalingo
# Processing Record 34 of Set 6 | cartagena del chaira
# Processing Record 35 of Set 6 | halalo
# Processing Record 36 of Set 6 | seoni malwa
# Processing Record 37 of Set 6 | laguna
# Processing Record 38 of Set 6 | aswan
# Processing Record 39 of Set 6 | selishche
# Processing Record 40 of Set 6 | boa vista
# Processing Record 41 of Set 6 | pemangkat
# Processing Record 42 of Set 6 | marsabit
# Processing Record 43 of Set 6 | fengrun
# Processing Record 44 of Set 6 | dawei
# Processing Record 45 of Set 6 | rio gallegos
# Processing Record 46 of Set 6 | ryazanovskiy
# Processing Record 47 of Set 6 | grand gaube
# Processing Record 48 of Set 6 | hobyo
# Processing Record 49 of Set 6 | polunochnoye
# Processing Record 50 of Set 6 | kuche
# Processing Record 1 of Set 7 | moundou
# Processing Record 2 of Set 7 | gangotri
# Processing Record 3 of Set 7 | lata
# Processing Record 4 of Set 7 | soe
# Processing Record 5 of Set 7 | sapozhok
# Processing Record 6 of Set 7 | santiago del estero
# Processing Record 7 of Set 7 | noumea
# Processing Record 8 of Set 7 | yar-sale
# Processing Record 9 of Set 7 | tumannyy
# Processing Record 10 of Set 7 | kerema
# Processing Record 11 of Set 7 | vazante
# Processing Record 12 of Set 7 | kolondieba
# Processing Record 13 of Set 7 | komsomolskiy
# Processing Record 14 of Set 7 | votkinsk
# Processing Record 15 of Set 7 | orange
# Processing Record 16 of Set 7 | pevek
# Processing Record 17 of Set 7 | wilmington
# Processing Record 18 of Set 7 | cockburn town
# Processing Record 19 of Set 7 | maymyo
# Processing Record 20 of Set 7 | carnarvon
# Processing Record 21 of Set 7 | gouyave
# Processing Record 22 of Set 7 | vilhena
# Processing Record 23 of Set 7 | alofi
# Processing Record 24 of Set 7 | fairbanks
# Processing Record 25 of Set 7 | phan rang
# Processing Record 26 of Set 7 | luganville
# Processing Record 27 of Set 7 | savinka
# Processing Record 28 of Set 7 | pachino
# Processing Record 29 of Set 7 | gdov
# Processing Record 30 of Set 7 | leningradskiy
# Processing Record 31 of Set 7 | dikson
# Processing Record 32 of Set 7 | moba
# Processing Record 33 of Set 7 | georgiyevka
# Processing Record 34 of Set 7 | pineville
# Processing Record 35 of Set 7 | san javier
# Processing Record 36 of Set 7 | aklavik
# Processing Record 37 of Set 7 | salihorsk
# Processing Record 38 of Set 7 | yuzhno-yeniseyskiy
# Processing Record 39 of Set 7 | kozlovka
# Processing Record 40 of Set 7 | carutapera
# Processing Record 41 of Set 7 | eldikan
# Processing Record 42 of Set 7 | mozarlandia
# Processing Record 43 of Set 7 | bengkulu
# Processing Record 44 of Set 7 | berlevag
# Processing Record 45 of Set 7 | sapa
# Processing Record 46 of Set 7 | fortuna
# Processing Record 47 of Set 7 | vung tau
# Processing Record 48 of Set 7 | diffa
# Processing Record 49 of Set 7 | urfa
# Processing Record 50 of Set 7 | panama city
# Processing Record 1 of Set 8 | boma
# Processing Record 2 of Set 8 | broken hill
# Processing Record 3 of Set 8 | sedalia
# Processing Record 4 of Set 8 | patacamaya
# Processing Record 5 of Set 8 | tura
# Processing Record 6 of Set 8 | torbay
# Processing Record 7 of Set 8 | pangai
# Processing Record 8 of Set 8 | nome
# Processing Record 9 of Set 8 | lerwick
# Processing Record 10 of Set 8 | satitoa
# Processing Record 11 of Set 8 | srednekolymsk
# Processing Record 12 of Set 8 | cabo san lucas
# Processing Record 13 of Set 8 | provideniya
# Processing Record 14 of Set 8 | verkhnyaya inta
# Processing Record 15 of Set 8 | funadhoo
# Processing Record 16 of Set 8 | atagay
# Processing Record 17 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 8 | baruun-urt
# Processing Record 19 of Set 8 | umm bab
# Processing Record 20 of Set 8 | katsuura
# Processing Record 21 of Set 8 | takestan
# Processing Record 22 of Set 8 | champerico
# Processing Record 23 of Set 8 | kopavogur
# Processing Record 24 of Set 8 | nelipyno
# Processing Record 25 of Set 8 | bundaberg
# Processing Record 26 of Set 8 | nalut
# Processing Record 27 of Set 8 | henties bay
# Processing Record 28 of Set 8 | tortoli
# Processing Record 29 of Set 8 | mahibadhoo
# Processing Record 30 of Set 8 | kuliyapitiya
# Processing Record 31 of Set 8 | wewak
# Processing Record 32 of Set 8 | saint pete beach
# Processing Record 33 of Set 8 | malwan
# Processing Record 34 of Set 8 | thompson
# Processing Record 35 of Set 8 | sofiysk
# Processing Record 36 of Set 8 | tezu
# Processing Record 37 of Set 8 | presidencia roque saenz pena
# Processing Record 38 of Set 8 | buseresere
# Processing Record 39 of Set 8 | tyup
# Processing Record 40 of Set 8 | viedma
# Processing Record 41 of Set 8 | san patricio
# Processing Record 42 of Set 8 | vissenbjerg
# Processing Record 43 of Set 8 | marcona
# Processing Record 44 of Set 8 | ozinki
# Processing Record 45 of Set 8 | tsumeb
# Processing Record 46 of Set 8 | toora-khem
# Processing Record 47 of Set 8 | san carlos
# Processing Record 48 of Set 8 | batouri
# Processing Record 49 of Set 8 | spirit river
# Processing Record 50 of Set 8 | zyryanskoye
# Processing Record 1 of Set 9 | coahuayana
# Processing Record 2 of Set 9 | zavyalovo
# Processing Record 3 of Set 9 | gorin
# Processing Record 4 of Set 9 | bay roberts
# Processing Record 5 of Set 9 | dauriya
# Processing Record 6 of Set 9 | wuwei
# Processing Record 7 of Set 9 | chippewa falls
# Processing Record 8 of Set 9 | yarovoye
# Processing Record 9 of Set 9 | beloha
# Processing Record 10 of Set 9 | kiruna
# Processing Record 11 of Set 9 | tuggurt
# Processing Record 12 of Set 9 | marystown
# Processing Record 13 of Set 9 | yichang
# Processing Record 14 of Set 9 | wahlstedt
# Processing Record 15 of Set 9 | tiznit
# Processing Record 16 of Set 9 | luba
# Processing Record 17 of Set 9 | inhuma
# Processing Record 18 of Set 9 | saundatti yellamma
# Processing Record 19 of Set 9 | dunda
# Processing Record 20 of Set 9 | marsh harbour
# Processing Record 21 of Set 9 | mbini
# Processing Record 22 of Set 9 | urumqi
# Processing Record 23 of Set 9 | richmond
# Processing Record 24 of Set 9 | sibolga
# Processing Record 25 of Set 9 | lazaro cardenas
# Processing Record 26 of Set 9 | sarangani
# Processing Record 27 of Set 9 | saint-pierre
# Processing Record 28 of Set 9 | puerto del rosario
# Processing Record 29 of Set 9 | kamenka
# Processing Record 30 of Set 9 | lagonoy
# Processing Record 31 of Set 9 | christchurch
# Processing Record 32 of Set 9 | muros
# Processing Record 33 of Set 9 | stafford
# Processing Record 34 of Set 9 | oloron-sainte-marie
# Processing Record 35 of Set 9 | zhangjiakou
# Processing Record 36 of Set 9 | hami
# Processing Record 37 of Set 9 | rosetta
# Processing Record 38 of Set 9 | pacific grove
# Processing Record 39 of Set 9 | mikasa
# Processing Record 40 of Set 9 | key largo
# Processing Record 41 of Set 9 | the valley
# Processing Record 42 of Set 9 | karla
# Processing Record 43 of Set 9 | souillac
# Processing Record 44 of Set 9 | northam
# Processing Record 45 of Set 9 | yola
# Processing Record 46 of Set 9 | zhangzhou
# Processing Record 47 of Set 9 | dudinka
# Processing Record 48 of Set 9 | paradwip
# Processing Record 49 of Set 9 | floro
# Processing Record 50 of Set 9 | koygorodok
# Processing Record 1 of Set 10 | ketchikan
# Processing Record 2 of Set 10 | sanchursk
# Processing Record 3 of Set 10 | lompoc
# Processing Record 4 of Set 10 | dahra
# Processing Record 5 of Set 10 | moranbah
# Processing Record 6 of Set 10 | katherine
# Processing Record 7 of Set 10 | san quintin
# Processing Record 8 of Set 10 | tiarei
# Processing Record 9 of Set 10 | pisco
# Processing Record 10 of Set 10 | salalah
# Processing Record 11 of Set 10 | panaba
# Processing Record 12 of Set 10 | cukai
# Processing Record 13 of Set 10 | lichuan
# Processing Record 14 of Set 10 | ankara
# Processing Record 15 of Set 10 | jambi
# Processing Record 16 of Set 10 | ambon
# Processing Record 17 of Set 10 | esperance
# Processing Record 18 of Set 10 | vengerovo
# Processing Record 19 of Set 10 | achisay
# Processing Record 20 of Set 10 | zhezkazgan
# Processing Record 21 of Set 10 | jiuquan
# Processing Record 22 of Set 10 | tatawin
# Processing Record 23 of Set 10 | ust-nera
# Processing Record 24 of Set 10 | nouadhibou
# Processing Record 25 of Set 10 | sungairaya
# Processing Record 26 of Set 10 | darab
# Processing Record 27 of Set 10 | itarema
# Processing Record 28 of Set 10 | aykhal
# Processing Record 29 of Set 10 | hinton
# Processing Record 30 of Set 10 | inirida
# Processing Record 31 of Set 10 | harindanga
# Processing Record 32 of Set 10 | gorkovskoye
# Processing Record 33 of Set 10 | moree
# Processing Record 34 of Set 10 | wichian buri
# Processing Record 35 of Set 10 | balabac
# Processing Record 36 of Set 10 | hervey bay
# Processing Record 37 of Set 10 | inhambane
# Processing Record 38 of Set 10 | tilichiki
# Processing Record 39 of Set 10 | eyl
# Processing Record 40 of Set 10 | kieta
# Processing Record 41 of Set 10 | loralai
# Processing Record 42 of Set 10 | ixtapa
# Processing Record 43 of Set 10 | nieuw amsterdam
# Processing Record 44 of Set 10 | sukumo
# Processing Record 45 of Set 10 | mutis
# Processing Record 46 of Set 10 | yeppoon
# Processing Record 47 of Set 10 | naberera
# Processing Record 48 of Set 10 | yuxia
# Processing Record 49 of Set 10 | lalomanu
# Processing Record 50 of Set 10 | meyungs
# Processing Record 1 of Set 11 | palabuhanratu
# Processing Record 2 of Set 11 | buqayq
# Processing Record 3 of Set 11 | amanganj
# Processing Record 4 of Set 11 | fevralsk
# Processing Record 5 of Set 11 | bandar-e lengeh
# Processing Record 6 of Set 11 | manitouwadge
# Processing Record 7 of Set 11 | gryazovets
# Processing Record 8 of Set 11 | touho
# Processing Record 9 of Set 11 | sur
# Processing Record 10 of Set 11 | paita
# Processing Record 11 of Set 11 | rodrigues alves
# Processing Record 12 of Set 11 | mangan
# Processing Record 13 of Set 11 | swift current
# Processing Record 14 of Set 11 | touros
# Processing Record 15 of Set 11 | moberly
# Processing Record 16 of Set 11 | kazachinskoye
# Processing Record 17 of Set 11 | nurota
# Processing Record 18 of Set 11 | mananjary
# Processing Record 19 of Set 11 | sabha
# Processing Record 20 of Set 11 | gustavo diaz ordaz
# Processing Record 21 of Set 11 | salina cruz
# Processing Record 22 of Set 11 | snasa
# Processing Record 23 of Set 11 | iquique
# Processing Record 24 of Set 11 | kawalu
# Processing Record 25 of Set 11 | havelock
# Processing Record 26 of Set 11 | medea
# Processing Record 27 of Set 11 | tirat karmel
# Processing Record 28 of Set 11 | tuatapere
# Processing Record 29 of Set 11 | nizwa
# Processing Record 30 of Set 11 | iranshahr
# Processing Record 31 of Set 11 | aksu
# Processing Record 32 of Set 11 | rongcheng
# Processing Record 33 of Set 11 | mirnyy
# Processing Record 34 of Set 11 | marawi
# Processing Record 35 of Set 11 | kysyl-syr
# Processing Record 36 of Set 11 | jati
# Processing Record 37 of Set 11 | bulgan
# Processing Record 38 of Set 11 | ambatondrazaka
# Processing Record 39 of Set 11 | kailua
# Processing Record 40 of Set 11 | paamiut
# Processing Record 41 of Set 11 | lagoa
# Processing Record 42 of Set 11 | lumeje
# Processing Record 43 of Set 11 | chifeng
# Processing Record 44 of Set 11 | bordighera
# Processing Record 45 of Set 11 | dofteana
# Processing Record 46 of Set 11 | almaznyy
# Processing Record 47 of Set 11 | ihosy
# Processing Record 48 of Set 11 | temple
# Processing Record 49 of Set 11 | shimoda
# Processing Record 50 of Set 11 | muroto
# Processing Record 1 of Set 12 | isla mujeres
# Processing Record 2 of Set 12 | zlatoustovsk
# Processing Record 3 of Set 12 | barbar
# Processing Record 4 of Set 12 | portland
# Processing Record 5 of Set 12 | borama
# Processing Record 6 of Set 12 | tasbuget
# Processing Record 7 of Set 12 | port moresby
# Processing Record 8 of Set 12 | kulhudhuffushi
# Processing Record 9 of Set 12 | kununurra
# Processing Record 10 of Set 12 | moose factory
# Processing Record 11 of Set 12 | batticaloa
# Processing Record 12 of Set 12 | naze
# Processing Record 13 of Set 12 | jaumave
# Processing Record 14 of Set 12 | jucuaran
# Processing Record 15 of Set 12 | lashio
# Processing Record 16 of Set 12 | uvalde
# Processing Record 17 of Set 12 | yulara
# Processing Record 18 of Set 12 | richards bay
# Processing Record 19 of Set 12 | zhuanghe
# Processing Record 20 of Set 12 | betioky
# Processing Record 21 of Set 12 | khorramshahr
# Processing Record 22 of Set 12 | cam pha
# Processing Record 23 of Set 12 | vagur
# Processing Record 24 of Set 12 | ust-kamchatsk
# Processing Record 25 of Set 12 | santa cruz de la palma
# Processing Record 26 of Set 12 | maragogi
# Processing Record 27 of Set 12 | puerto quijarro
# Processing Record 28 of Set 12 | mana
# Processing Record 29 of Set 12 | ponnani
# Processing Record 30 of Set 12 | arman
# Processing Record 31 of Set 12 | tebingtinggi
# Processing Record 32 of Set 12 | cabrobo
# Processing Record 33 of Set 12 | maromitsa
# Processing Record 34 of Set 12 | rulenge
# Processing Record 35 of Set 12 | parfenyevo
# Processing Record 36 of Set 12 | san jeronimo
# Processing Record 37 of Set 12 | zhangye
# Processing Record 38 of Set 12 | amderma
# Processing Record 39 of Set 12 | santa maria
# Processing Record 40 of Set 12 | hailar
# Processing Record 41 of Set 12 | severomuysk
# Processing Record 42 of Set 12 | camacupa
# Processing Record 43 of Set 12 | saleaula
# Processing Record 44 of Set 12 | hammerfest
# Processing Record 45 of Set 12 | lavrentiya
# Processing Record 46 of Set 12 | kaeo
# Processing Record 47 of Set 12 | barmer
# Processing Record 48 of Set 12 | matara
# Processing Record 49 of Set 12 | guanica
# Processing Record 50 of Set 12 | heishan
# Processing Record 1 of Set 13 | mayor pablo lagerenza
# Processing Record 2 of Set 13 | namanga
# Processing Record 3 of Set 13 | quatre cocos
# Processing Record 4 of Set 13 | ejea de los caballeros
# Processing Record 5 of Set 13 | keetmanshoop
# Processing Record 6 of Set 13 | taburi
# Processing Record 7 of Set 13 | beyneu
# Processing Record 8 of Set 13 | sawakin
# Processing Record 9 of Set 13 | ola
# Processing Record 10 of Set 13 | lipin bor
# Processing Record 11 of Set 13 | imperatriz
# Processing Record 12 of Set 13 | pontalina
# Processing Record 13 of Set 13 | rio grande
# Processing Record 14 of Set 13 | warqla
# Processing Record 15 of Set 13 | praya
# Processing Record 16 of Set 13 | maloy
# Processing Record 17 of Set 13 | humberto de campos
# Processing Record 18 of Set 13 | tsihombe
# Processing Record 19 of Set 13 | asau
# Processing Record 20 of Set 13 | cabedelo
# Processing Record 21 of Set 13 | sechura
# Processing Record 22 of Set 13 | cayenne
# Processing Record 23 of Set 13 | havre-saint-pierre
# Processing Record 24 of Set 13 | los algarrobos
# Processing Record 25 of Set 13 | telixtlahuaca
# Processing Record 26 of Set 13 | togur
# Processing Record 27 of Set 13 | olafsvik
# Processing Record 28 of Set 13 | tongchuan
# Processing Record 29 of Set 13 | darhan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = # YOUR CODE HERE

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0            Bluff -46.6000  168.3333     56.80          few clouds        68
# 1            Metro  -5.1131  105.3067     88.48     overcast clouds        54
# 2    Pacific Grove  36.6177 -121.9166     64.08           clear sky        87
# 3     Saint George  37.1041 -113.5841     79.95           clear sky        40
# 4          Mataura -46.1927  168.8643     56.48          few clouds        56
# 5          Biltine  14.5333   20.9167     80.42    scattered clouds        61
# 6              Gao  16.6362    1.6370     85.73       broken clouds        47
# 7        Hithadhoo  -0.6000   73.0833     82.00    scattered clouds        72
# 8  Bambous Virieux -20.3428   57.7575     76.21       broken clouds        78
# 9          Rikitea -23.1203 -134.9692     73.35           clear sky        72
#
#    Cloudiness  Wind Speed Country
# 0          21        2.28      NZ
# 1          92        4.52      ID
# 2           0        4.61      US
# 3           0       10.36      US
# 4          15        2.44      NZ
# 5          27        3.36      TD
# 6          77        6.31      ML
# 7          47        7.78      MV
# 8          75       13.80      MU
# 9           3       14.23      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Importing Pandas to create DataFrame
import pandas as pd
  
# Creating Empty DataFrame and Storing it in variable df
df = pd.DataFrame()

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_data/cities.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
